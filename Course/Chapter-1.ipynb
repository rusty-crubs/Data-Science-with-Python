# %% [markdown]
# # Chapter 1: Introduction to Python
# ## 1.1 Introduction
# Python is one of the most popular programming languages. It's simple to use, packed with features and support by wide range of libraries and frameworks. Its clean syntax makes it beginner-friendly.
#
# - A high-level language, used in data science, automation, AI, Web development and more.
# - Known for its readibility, which means code is easier to write, understand and maintain.
# - Backed by strong library support, we don't have to build everything from scratch (like C/C++).

# %% [markdown]
# Python is dynamic, interpreted (bytecode-compiled) language. There are no type variables, parameters, functions, or methods in source code. This makes the code short and flexible, and lose the compile-time type checking of the source code. Python tracks the types of all values at runtime and flags code that does not make sense as it runs.

# %% [markdown]
# ## 1.2 Installation of Python
# For different Operating System (OS), there are various method and process to install **Python** like in Unix/Linux they are already pre-installed but in some cases ( as there are many distribution of Linux system ) Python might have not been install, You could install Python by writting following command in its terminal:

# %% [markdown]
# - **$ sudo apt-get install Python3** => for debian based Linux.
#
# - **$ sudo pacman -Sy Python3** => for Arch based Linux.

# %% [markdown]
# For windows, we are going to install **[anaconda](anaconda.com/downloads)** in the system. In anaconda, there are many libraries which will become essential in the journey of coding field like **Data Science**, **Data Analysis**,**Web deveploment**, and so on. Download it from its download page, run the download file, and click next and choose to implement for whole system as you can connect the Python file and library into various Integrated Development Environments(IDEs).

# %% [markdown]
# Open Command prompt or terminal of the system and run **Python3 --version**, this should give you output like: **Python3.xx.x** version, anaconda will always gives you the latest version of python with updated libraries on current time.

# %% [markdown]
# ## Basic Syntax, Variable, Keyword and expression

# %% [markdown]
# ### 1.3.1 Input/Output
# Python program is written in **.py** extension. But this one is written in Jupyter Notebook, if you like to write this form of notes in your device you can open **Jupyter Notebook** from **Anaconda Navigation** application present in your windows OS. In Linux, You can use **Jupyter Notebook** by installing it. Open your terminal, and write this following command:

# %% [markdown]
# - **$ sudo apt-get install jupyter-notebook** --> For debian distro
#
# - **$ yay -Syu jupyter-notebook** --> for arch distro

# %% [markdown]
# **Note**:If you are using anyother distribution, you can search in google on how to install it.

# %% [markdown]
# **Learning objective**
#
# By the end of this section you will be able to:
# - Display output using print() function.
# - Obtain User data using input() function.

# %% [markdown]
# #### Basic Output
# The print() function displays output to user. Output is the information or result by a program. The sep and end options be used to customize the output.
#
# Multiple values seperated by commas, can be printed in the same statement. By default, each value is seperated by a space character in the ouput. The sep option can be used to change this behaviour.
#
# By defaut print() function adds a newline character at the end of the output. A **newline** character tells the display to move the line to next line. The end option can be used to continue printing in same line.

# %%
print("Today is Monday!!!")
print("I like string beans.")
# Out:
# Today is Monday!!!
# I like string beans.

# %%
print("Today","is", "monday!!!")
print("Today", "is", "Monday!!!",sep="...")
# Out:
# Today is monday!!!
# Today...is...Monday!!!

# %%
print("Today is Monday!!!, ", end="")
print("I like string beans.")
# Out:
# Today is Monday!!!, I like string beans.

# %%
print("Today","is","Monday,", sep="??", end="!!")
print("I like string beans.")
# Out:
# Today??is??Monday,!!I like string beans.

# %% [markdown]
# #### Basic Input
# Computer programs often receive input from the user. Input is what a user enters into a program. An input statement, variable = **input("Prompt")**, has three parts:
#
# 1. A **variable** refers to value stored in memory. In the statement above, variable cab be replaced with any name the programmer chooses.
# 2. The **input()** function reads oneline of input from the user. A function us a named, reusable block of code that performs a task when called. The input is stored in the computer's memory and can be accessed later using the variable.
# 3. A **prompt** is a short message that indicates the program is waiting for input. In the statement above, "promt" cab be imitted or replace with any message.

# %%
value_A = int(input("Enter any value"))
value_A
# Out:
# Enter any value 25
# 25

# %%
name = input("Enter your name")
name
# Out:
# Enter your name Rajandra Prasad
# 'Rajandra Prasad'

# %% [markdown]
# ==> By Combining this Input and Output you cold create a form to get data and calculate using any form of scientific equation, and print it:

# %%
m = int(input("Enter the mass of the object"))
g = 9.8
f = m * g
print(f"Force(F)={f}")
# Out:
# Enter the mass of the object 2000
# Force(F)=19600.0

# %% [markdown]
# ### 1.3.2 Variables
# **Learning Objective**
#
# By the end of this section you should be able to:
# - Assign variables and print variables.
# - Explain rules for naming variables.

# %% [markdown]
# A statement can set a variable to value using the assignment operation (=).

# %% [markdown]
# Variables allows programs to refer to values using names rather than memory location. Example:

# %%
age = 68

# %% [markdown]
# from the above we can understand that a person age is 68 years old.

# %%
city = "Pokhara"
print(f"Most visited city of Nepal is {city}")
# Out:
# Most visited city of Nepal is Pokhara

# %%
temperature = 0
print(f"This year winter temperature was about {temperature} deg Celsius")
# Out:
# This year winter temperature was about 0 deg Celsius

# %% [markdown]
# ### Variable naming rules
# - A variable name can consist of letter, digits, and underscores and be of any length.
# - The name cannot start with a digit. Example 101class is invalid.
# - Letter case matters. Example: Total is different from total.
# - Recommended to write variable names in **snake case**, which is all lowercase with underscores in between each words, such as first_name and Last_name.

# %% [markdown]
# Python has reserved **Keywords**, which have special functions and cannot be used as names for variables (for other objects).
# ![Keywords](https://kodekloud.com/kk-media/image/upload/v1752883525/notes-assets/images/Python-Basics-Variables/frame_110.jpg)

# %% [markdown]
# ## 1.4 Data types

# %% [markdown]
# ### 1. String
# **Learning Objective**
#
# By the end of this section, you should be able to:
# - Use the built-in term len() fuction to get a string's length.
# - Concatenate string literals and variables using the + operatior.

# %% [markdown]
# A string is a sequence of characters enclosed by matching single(' ') or double (" ") quotes. Example: "Happy Birthday!!!" and '21' are both strings.

# %%
wish = "Happy Birthday"
wish
# Out:
# 'Happy Birthday'

# %%
date = "21th febrary"
date
# Out:
# '21th febrary'

# %% [markdown]
# ### len() function
# A common operation on a string object to get the string length, or the number of the characters in the string. The len() function, when called on a string value, returns the string length. Example:

# %%
len(date)
# Out:
# 12

# %% [markdown]
# The length of the date variable is of 12 character long.

# %% [markdown]
# ### Concatenation
# Concatenation is an operation that combines two or more strings sequentially with the concatenation operator(+). Example:

# %%
date + " " + wish
# Out:
# '21th febrary Happy Birthday'

# %% [markdown]
# or

# %%
print(date + " " + wish)
# Out:
# 21th febrary Happy Birthday

# %% [markdown]
# ### 2. Number basis
# **Learning Objective**
#
# By the end of this section you should be able to:
# - Use arithmetic operators to perform calculation.
# - Explain the precedence of arithmetic operators.

# %% [markdown]
# Python supports two basic number formate, integer and floating point. An integer represents a whole number, and a floating point format represents a decimal number. The format a language uses to represent data is called a **data type**. In addition to integer and floating types, programming language typically have string type for representing text.

# %%
x = 16
x,type(x)
# Out:
# (16, int)

# %%
x = 18.0
x,type(x)
# Out:
# (18.0, float)

# %% [markdown]
# ### Basic arithmetic
# **Arithmetic operations** are used to perform mathematical operations like addition, subtraction, multiplication and division.
#
# Four basic arithmetic operators exist in Python:
# 1. Addition(+)
# 2. Subtraction(-)
# 3. Multiplication(*)
# 4. Division(/)
#
# Example:

# %%
x = 10
y = 30

# Addition
print(f"Add {x} by {y} is {x+y}")

# Subtraction
print(f"Subtract {x} by {y} is {x-y}")

# Multiplication
print(f"Multiply {x} by {y} is {x*y}")

# Division
print(f"Disision of {x} by {y} is {x/y}")
# Out:
# Add 10 by 30 is 40
# Subtract 10 by 30 is -20
# Multiply 10 by 30 is 300
# Disision of 10 by 30 is 0.3333333333333333

# %% [markdown]
# we can also find the power value by placing two astrics (*) sign

# %%
2**3
# Out:
# 8

# %% [markdown]
# ### 3. Boolean
# Boolean is a computational operation of true and false of the statement. Its generally used in loops.

# %% [markdown]
# ### 4. Type Conversion
# **Learning Objective**
#
# By the end of this section, you should be able to:
# - Convert the string numeric value to numeric value and vice versa.

# %% [markdown]
# Type conversion is the conversion of a data from one data type to another, but you need to know that only numerical value are being process for conversion.

# %%
x="1e3"
x
# Out:
# '1e3'

# %%
int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 int(x)
#
# ValueError: invalid literal for int() with base 10: '1e3'

# %% [markdown]
# It gives error if it find any alphabetical values in the variable.

# %%
x = "10000"
x
# Out:
# '10000'

# %%
int(x)
# Out:
# 10000

# %% [markdown]
# Now, we have converted it to an integer variable. If you want float, you can replace int() data type with float() data type.

# %% [markdown]
# ## 1.5 Error Messages
# **Learning objective**
#
# By the end of this section, you should be able to:
# - Identify the error type and line number in error message.
# - Correct syntax error, name error, and indentation errors.

# %% [markdown]
# A natural part of programming is making mistakes. Even experienced programmers makes mistakes when writing code. The computer requires very specific instructions telling the computer what to do. If the instructions are not clear, then the computer does not know what to do and give back an error.
#
# When an error occurs, Python displays a message with the following information:
# 1. The line number of the error.
# 2. The type of error (Example: Syntax Error).
# 3. Additional details about the error.

# %% [markdown]
# Ex: Typing print "Hello!" without parentheses is a syntax error. In Python, parentheses are required to use
# print. When attempting to run print "Hello!", Python displays the following error:
#
# Traceback (most recent call last):
#
# File "/home/student/Desktop/example.py", line 1
#
# print "Hello"
#
# ^
#
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello")?

# %% [markdown]
# The caret character (^) shows where Python found the error. Sometimes the error may be located one or two lines before where the caret symbol is shown because Python may not have discovered the error until then. **Traceback** is a Python report of the location and type of error. The word traceback suggests a programmer trace back in the code to find the error if the error is not seen right away.
