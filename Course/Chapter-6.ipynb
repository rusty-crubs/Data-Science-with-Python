# %% [markdown]
# # Chapter 6: Data Visualization with Matplotlib and Seaborn

# %% [markdown]
# ## 1. Importance of Visualization in Data Science
# - In today's world, alot of data is being generated on a daily basis, and sometimes to analyze this data for certain trends, patterns may become difficult if the data is in its raw format.
# - Data visualization provides a good organized pictorial representation of the data which makes it easier to understand, observem analyze.
# - Python provides libraries that come with different features for visualizing data. All these libraries comes with different features and can support various types of graphs.
#   - Matplotlib
#   - Seaborn
#   - Bokeh
#   - Plotly

# %% [markdown]
# ## 2. Plotting basics using Matplotlib
# - Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations.
# - Matplotlib is a widely used Python library for creating static, publication-quality 2D (and basic 3D) plots.
# - It provides low-level control over every element of a figure and serves as the foundation for higher-level libraries like Seaborn and pandas plotting.
# - Installation of Matplotlib: To install Matplotlib, you could simply run:
# > pip install matplotlib
# - In any terminal.
# - **Key Concepts**:
#   1. Figure: the overall window or page that contains one or more plots.
#   2. Axes: an individual plot area inside a Figure (contains x/y axis, labels, title, data).
#   3. Artist: any visual element drawn on the canvas (line, text, ticks, patches).
#   4. Backend: the renderer/GUI or file-output system (e.g., Agg for PNG, PDF, interactive backends for notebooks or desktop).
# - Two main interfaces
#   1. pyplot (state-machine style): convenience functions modeled after MATLAB (plt.figure(), plt.plot(), plt.show()). Good for quick scripts and interactive work.
#   2. Object-oriented (OO) API: create Figure and Axes objects and call methods on them (fig, ax=plt.subplots(); ax.plot(...)). Preferred for complex figures, reproducibility, and reusable code.

# %% [markdown]
# ### Figures
# - Matplotlib graphs data on Figures, each of which can contain one or more Axes, an area where points can be specified in terms of x-y coordinates (or theta-r in a polar plot, x-y-z in 3D plot etc).
# - The simplest way of creating a Figure with an Axes is using subplots.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot([1,2,3,4],[1,4,2,3])
plt.show()

# %% [markdown]
# ### Parts of a Figure
# Here are the components of a Matplotlib Figure.
# ![Figure](https://matplotlib.org/stable/_images/anatomy.png)
#
# ### Figure
# - The whole figure. The figure keeps track of all child Axes, a group of 'special' Artists (titles, figure legends, colorbars,etc.) and even nested subfigures.
# - Typically, you can create a new Figure through one of the following functions:
# ``` Python
# fig=plt.figure() # an empty figure with no Axes
# fig, ax = plt.subplots() # a figure with a single Axes
# fig, axs = plt.subplot(2, 2) # a figure with a 2X2 grid of Axes
# # a figure with one Axes on the left, and two on the right
# fig, axs= plt.subplot_mosaic([['left', 'right_top'],
# 'left','right_bottom'])
# ```
# - subplots() and subplot_mosaic() are convenience functions that additionally create Axes objects inside the Figure, but you can also manually add Axes later on.

# %% [markdown]
# ### Axes
#
# - An Axes is an Artist attached to a Figure that contains a region for plotting data, and usually includes two (or three in the case of 3D) Axis objects (be aware of the difference between Axes and Axis) that provide ticks and tick labels to provide scales for the data in the Axes. Each Axes also has a title (set via set_title()), an x-label (set via set_xlabel()), and a y-label set via set_ylabel()).
# - The Axes methods are the primary interface for configuring most parts of your plot (adding data, controlling axis scales and limits, adding labels etc.).
#
# ### Axis
# - These objects set the scale and limits and generate ticks (the marks on the Axis) and ticklabels (strings labeling the ticks). The location of the ticks is determined by a Locator object and the ticklabel strings are formatted by a Formatter. The combination of the correct Locator and Formatter gives very fine control over the tick locations and labels.
#
# ### Artist
# - Basically, everything visible on the Figure is an Artist (even Figure, Axes, and Axis objects). This includes Text objects, Line2D objects, collections objects, Patch objects, etc. When the Figure is rendered, all of the Artists are drawn to the canvas. Most Artists are tied to an Axes; such an Artist cannot be shared by multiple Axes, or moved from one to another.

# %% [markdown]
# ## Using Tips database
# - Tips database is the record of the tips given by the costumers in a restaurant for two and a half months in the early 1990s.
# - It consists of 6 columns such as total bill, tips, sex, smoker, day, time, size.

# %%
tips = 'https://media.geeksforgeeks.org/wp-content/uploads/tips.csv'

# %%
import pandas as pd

df = pd.read_csv(tips)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Scatter Plot
# - Scatter plots are used to observe relationships between variables and uses dots to represent the relationship between them.
# - The scatter() method in the matplotlib library is used to draw a scatter plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reading tips
# tips is defined at Using Tip Database section
data = pd.read_csv(tips)

# Scatter plot with day against tips
plt.scatter(data['day'],data['tip'])

# Title
plt.title('Scatter Plot')

# Setting X and Y label
plt.xlabel('Day')
plt.ylabel('Tip')

plt.show()

# %% [markdown]
# This graph can be more meaningful if we can add colors and also change the size of the points. We can do this by using 'c' and 's' parameter respectively of the scatter function. we can also show the color bar using the colorbar() method.

# %%
# Changing colors and size
plt.scatter(data['day'],data['tip'],c=data['size'],s=data['total_bill'])
plt.colorbar()

# %% [markdown]
# ### Line Chart
# - Line chart is used to represent a relationship between two data X and Y on a different axis.
# - It is plotted using plot() function.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Reading tips, defined at Using Tip Database
data = pd.read_csv(tips)

# Line plot with tip and size
plt.plot(data['tip'])
plt.plot(data['size'])

# Adding Title to the plot
plt.title('Line Chart')

# Setting X and Y label
plt.xlabel('Day')
plt.ylabel('tips')

plt.show()

# %% [markdown]
# ### Bar plot
# - A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent.
# - It can be created using the bar() method.

# %%
import matplotlib.pyplot as plt
import pandas as pd 

# reading tip
data = pd.read_csv(tips)

# Bar Chart with day against tip
plt.bar(data['day'], data['tip'])

# title
plt.title('Bar Chart')

# setting X and Y label
plt.xlabel('Day')
plt.ylabel('tips')

plt.show()

# %% [markdown]
# ### Histogram
# - A histogram is basically used to represent data in the form of some groups.
# - It is a type of bar plot where the X-axis represents the bin ranges while the Y-axis gives information about frequency
# - The hist() function is used to compute and create a histogram.
# - In histogram, if we pass categorical data then it will automatically compute the frequency of that data, i.e. how often each value occurred.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# reading the database
data=pd.read_csv(tips)

# histogram of total_bill
plt.hist(data['total_bill'])

# Title
plt.title('Histogram')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Making a helper function
# - If you need to make the same plots over and over again with different data sets, or want to easily wrap Matplotlib methods, use the recommended signature figure function below:

# %%
def plotter(ax, data1, data2, param_dict):
    # A helper function to make a graph
    out = ax.plot(data1, data2, **param_dict)
    return out

# %% [markdown]
# which you would then use twice to populate two subplots:

# %%
import numpy as np
import matplotlib.pyplot as plt

# initializing data
data1, data2, data3, data4 = np.random.randn(4,100)

# Subplotting through fig method
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(5, 2.7))

plotter(ax1, data1, data2, {'marker':'x'})
plotter(ax2, data3, data4, {'marker':'o'})

# %% [markdown]
# ### Styling Artists
# Most plotting methods have styling options for the Artists, accessible either when a plotting method is called, or from a 'setter' on the Artist. In the plot below we manually set the color, linewidth, and linestyle of the Artists created by plot, and we set the linestyle of the second line after the fact with set_linestyle.

# %%
fig, ax = plt.subplots(figsize=(5,2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle='--')
l, = ax.plot(x, np.cumsum(data2), color='orange', linewidth=2)
l.set_linestyle(':')

# %% [markdown]
# ### Color
# - Matplotlib has a very flexible array of colors that are accepted for most Artists/
# - Some Artists will take multiple colors, i.e. for a scatter plot, the edge of the markers can be different colors from the interior:

# %%
fix, ax = plt.subplots(figsize=(5,2.7))
ax.scatter(data1, data2, s=50, facecolor='C0', edgecolor='k')

# %% [markdown]
# ### Linewidth, Linestyle, and markersizes
# - Line widths are typically in typographic points (1 pt = 1/72 inch) and available for Artists that have stroked lines.
# - Marker size depends on the method being used. plot specifies marksize in points, and is generally the 'diameter' or width of the marker. scatter specifies markersize as approximately proportional to the visual area of the marker.

# %%
fig, ax = plt.subplots(figsize=(5,2.7))
ax.plot(data1, 'o', label='data1')
ax.plot(data2, 'd', label='data2')
ax.plot(data3, 'v', label='data3')
ax.plot(data4, 's', label='data4')

# %% [markdown]
# ## Labelling plots
# ### Axes labels and text
# set_xlabel, set_ylabel, and set_title are used to add text in the indicated locations.

# %%
import numpy as np
import matplotlib.pyplot as plt
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
# the histogram of the data
n, bins, patches = ax.hist(x, 50, density=True, facecolor='C0', alpha=0.75)

ax.set_xlabel('Length [cm]')
ax.set_ylabel('Probability')
ax.set_title('Aardvark lengths\n (not really)')
ax.text(75, .025, r'$\mu=115,\ \sigma=15$')
ax.axis([55, 175, 0, 0.03])
ax.grid(True)

# %% [markdown]
# ### Annotations
# - We can also annotate points on a plot, often by connecting an arrow pointing to xy, to a piece of text at xy text.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5, 2.7))

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2,1), xytext=(3, 1.5), arrowprops=dict(facecolor='black', shrink=0.05))
ax.set_ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %% [markdown]
# ### Legends
# - A legends in matplotlib is a boxed area on a plot that explains what plotted elements (line, markers, patches, etc.) represent by showing labels and corresponding symbols or colors.
# - It helps readers map visual elements to data series or categories.

# %%
import numpy as np 
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(np.arange(len(data1)), data1, label='data1')
ax.plot(np.arange(len(data2)), data2, 'v',label='data2')
ax.plot(np.arange(len(data3)), data3, 'd',label='data3')
ax.legend()

# %% [markdown]
# ## Seaborn
# - Seaborn is a high-level interface built on top of the Matpotlib.
# - It provides beautiful design styles and color palettes to make more attractive graphs.
# - **Installation of Seaborn**: To install seaborn, type the following in your terminal:
# > pip install seaborn
# - Seaborn is built on top of Matplotlib, therefore, it can be used with the Matplotlib as well.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# reading the database
data = pd.read_csv(tips)

# drawing lineplot
sns.lineplot(x='sex', y='total_bill', data=data)

# setting the title using Matplotlib
plt.title('Title using Matplotlib Funtion')

plt.show()

# %% [markdown]
# ### Scatter Plot
# - Scatter plot is plotted using the scatterplot() method.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# reading the database
data=pd.read_csv(tips)

sns.scatterplot(x='day', y='tip', data=data)
plt.show()

# %% [markdown]
# You will find that while using Matplotlib it will be a lot difficult if you want to color each point of this plot according to the sex. But in scatter plot it can be done with the help of hue argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# reading the database
data=pd.read_csv(tips)

sns.scatterplot(x='day', y='tip', data=data, hue='sex')
plt.show()

# %% [markdown]
# ### Line Plot
# - Line plot in Seaborn plotted using lineplot().

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# reading the database
data = pd.read_csv(tips)

sns.lineplot(x='day', y='tip', data=data)
plt.show()

# %%
sns.lineplot(data=data.drop(['total_bill'], axis=1))
plt.show()

# %% [markdown]
# ### Bar Plot
# - Bar Plot in Seaborn can be created using the barplot() method.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# reading the database
data = pd.read_csv(tips)

sns.barplot(x='day', y='tip', data=data, hue='sex')
plt.show()

# %% [markdown]
# ### Histogram
# - This histogram in Seaborn can be plotted using the histplot() function.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# reading the database
data = pd.read_csv(tips)

sns.histplot(x='total_bill',data=data, kde=True, hue='sex')
plt.show()
