# %% [markdown]
# # Linear regression using scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('automobileEDA.csv')

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
# 3               10.0       102.0    5500.0       24          30  13950.0
# 4                8.0       115.0    5500.0       18          22  17450.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
# 3     9.791667             Medium       0    1
# 4    13.055556             Medium       0    1
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Y = MX + C
# ### y = wx + b
# models are unique variable or univariet.

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
X = df[["horsepower"]].values
Y = df['price'].values

# %%
sns.regplot(x="horsepower", y="price", data=df)
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>

# %%
# model.fit(X.reshape(-1, 1), Y)
# print(model.intercept_, model.coef_)

# %%
print(model.coef_ , model.intercept_)
# Out:
# [172.18312191] -4597.55829789292

# %%
w = model.coef_
b = model.intercept_

# %%
y = w * X + b

# %%
y[0:5]
# Out:
# array([[14514.76823442],
#        [14514.76823442],
#        [21918.64247666],
#        [12965.1201372 ],
#        [15203.50072207]])

# %%
y_pred = model.predict(X)
y_pred[0:5]
# Out:
# array([14514.76823442, 14514.76823442, 21918.64247666, 12965.1201372 ,
#        15203.50072207])

# %% [markdown]
# # Multiple Linear Regression
# feature variable could be one or more than one.

# %%
x = df[["horsepower", "engine-size", "highway-mpg"]]
y = df["price"]

# %%
multi_ln = LinearRegression()
multi_ln.fit(x, y)
# Out:
# LinearRegression()

# %%
multi_ln.coef_
# Out:
# array([  41.17449204,  120.85329253, -139.42625264])

# %%
multi_ln.intercept_
# Out:
# np.float64(-2105.3645609525993)
