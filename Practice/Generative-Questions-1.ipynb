# %% [markdown]
# ### **Python Programming for Data Science (ENCT 329)**
# **Final Exam**
# **Total Marks: 60**
# **Time: 3 Hours**
#
# ---
#
# **Section A: Attempt ALL questions from this section.**

# %% [markdown]
# **Question 1** (Based on Chapter 1: Introduction) **[10 Marks]**
# a) Explain the significance of Python in the field of data science compared to other languages. List four key Python libraries used for different stages of data analysis. (5)
#
# b) Discuss various ways of type conversion in Python. Provide Python code examples to demonstrate implicit and explicit type conversion. (5)

# %% [markdown]
# **Question 2** (Based on Chapter 2: Control Structures and Functions) **[12 Marks]**
# a) Distinguish between `while` loops and `for` loops with appropriate examples. Explain the use of `break` and `continue` statements with code snippets. (6)
#
# b) What are lambda functions in Python? Explain with an example of how they differ from regular named functions. When is it appropriate to use a lambda function? (6)

# %% [markdown]
# **Question 3** (Based on Chapter 3: Data Structures and Collections) **[10 Marks]**
# a) Compare and contrast Lists, Tuples, and Dictionaries in Python based on their syntax, mutability, and common use cases. (6)
#
# b) What is list comprehension? Write a Python program using list comprehension to create a list of squares for all even numbers between 1 and 20. (4)

# %% [markdown]
# **Question 4** (Based on Chapter 4: NumPy for Numerical Computing) **[8 Marks]**
# a) What is a NumPy array, and how is it different from a Python list? Discuss the advantages of using NumPy arrays for numerical computation. (4)
#
# b) Given a 2D NumPy array, demonstrate how to perform indexing and slicing to extract specific rows and columns. Provide a code example. (4)

# %% [markdown]
# **Section B: Attempt ALL questions from this section.**

# %% [markdown]
# **Question 5** (Based on Chapter 5: Data Manipulation with Pandas) **[10 Marks]**
# a) Describe the `DataFrame` and `Series` objects in Pandas. Explain how data is typically imported into a Pandas DataFrame from common file formats like CSV. (5)
#
# b) Illustrate with code examples how to handle missing values and filter rows based on specific conditions in a Pandas DataFrame. (5)

# %% [markdown]
# **Question 6** (Based on Chapter 6: Data Visualization with Matplotlib and Seaborn) **[10 Marks]**
# a) Create a Matplotlib script to generate a line graph representing sales data over time. Your plot must include a title, x and y-axis labels, and a legend. (5)
#
# b) Explain the utility of a boxplot and a heatmap in statistical visualization. Provide a conceptual scenario where a heatmap generated with Seaborn would be more insightful than a standard scatter plot. (5)
